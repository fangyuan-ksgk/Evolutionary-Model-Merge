# %%
import subprocess
# command = ['modal', 'run', 'merge.py', '--unique-id', '0.56-0.15-0.77-0.2-0.48-0.51']
subprocess.call(command)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/fangyuanyu/.cache/huggingface/token
# Login successful
# ✓ Initialized. View run at
# https://modal.com/fangyuan-ksgk/apps/ap-eUvHRyB1RrMHRy1vvCXRKi
# ⠋ Initializing...
# ⠦ Creating objects...objects...
# ⠏ Creating objects...fig: Uploaded 0/0 inspected files
# ⠹ Creating objects...fig: Uploaded 0/0 inspected files
# ⠴ Creating objects...fig: Uploaded 0/0 inspected files
# ⠏ Creating objects...fig: Building mount
# ⠹ Creating objects...fig: Building mount
# ⠴ Creating objects...
# ⠇ Creating objects...
# ⠙ Creating objects...
# ⠴ Creating objects...
# ⠇ Creating objects...
# ⠙ Creating objects...
# ⠼ Creating objects...
# ⠧ Creating objects...
# ⠋ Creating objects...
# ⠼ Creating objects...
# ⠧ Creating objects...
# ⠋ Creating objects...
# ⠸ Creating objects...
# ...
